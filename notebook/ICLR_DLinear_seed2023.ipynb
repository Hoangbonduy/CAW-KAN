# %%
import os
import kagglehub
from google.colab import userdata

# 1. Gọi token từ Colab Secrets đúng với tên bạn đã lưu là 'ICLR'
os.environ['KAGGLE_TOKEN'] = userdata.get('ICLR_4')

# 2. Tải dataset với đường dẫn chính xác (chỉ định version 2)
path = kagglehub.dataset_download("Hoangbonduy/DLinear-2023seed/versions/1")

print(f"Dữ liệu đã được tải về ổ cứng tạm tại đường dẫn: {path}")
# Out:
# ...
# 100%|██████████| 94.3M/94.3M [00:00<00:00, 223MB/s]
# Extracting files...
# Dữ liệu đã được tải về ổ cứng tạm tại đường dẫn: /root/.cache/kagglehub/datasets/Hoangbonduy/DLinear-2023seed/versions/1

# %%
# 1. Đi sâu vào trong thư mục CAW-KAN
# %cd /root/.cache/kagglehub/datasets/Hoangbonduy/DLinear-2023seed/versions/1/DLinear

# 2. Cài đặt các thư viện cần thiết
# !pip install -r requirements_TimeKAN.txt
# Out:
# /root/.cache/kagglehub/datasets/Hoangbonduy/DLinear-2023seed/versions/1/DLinear
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 104.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 8.4 MB/s eta 0:00:00
# ...

# %%
# !sed -i 's/\r$//' scripts/EXP-LongForecasting/DLinear/etth1.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/EXP-LongForecasting/DLinear/etth1.sh

# 3. Chạy script
# !./scripts/EXP-LongForecasting/DLinear/etth1.sh
# Out:
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_512_96', model='DLinear', data='ETTh1', root_path='./dataset/', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=96, individual=False, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.05, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=8, patience=3, learning_rate=0.0001, des='Exp', loss='mse', lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# >>>>>>>start training : ETTh1_512_96_DLinear_ETTh1_ftM_sl512_ll48_pl96_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8033
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.4207245
# ...

# %%
# !sed -i 's/\r$//' scripts/EXP-LongForecasting/DLinear/etth2.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/EXP-LongForecasting/DLinear/etth2.sh

# 3. Chạy script
# !./scripts/EXP-LongForecasting/DLinear/etth2.sh
# Out:
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh2_512_96', model='DLinear', data='ETTh2', root_path='./dataset/', data_path='ETTh2.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=96, individual=False, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.05, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.05, des='Exp', loss='mse', lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# >>>>>>>start training : ETTh2_512_96_DLinear_ETTh2_ftM_sl512_ll48_pl96_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8033
# val 2785
# test 2785
# 	iters: 100, epoch: 1 | loss: 0.6336709
# ...

# %%
# !sed -i 's/\r$//' scripts/EXP-LongForecasting/DLinear/ettm1.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/EXP-LongForecasting/DLinear/ettm1.sh

# 3. Chạy script
# !./scripts/EXP-LongForecasting/DLinear/ettm1.sh
# Out:
# Args in experiment:
# Namespace(is_training=1, model_id='ETTm1_512_96', model='DLinear', data='ETTm1', root_path='./dataset/', data_path='ETTm1.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=96, individual=False, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.05, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=8, patience=3, learning_rate=0.0001, des='Exp', loss='mse', lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# >>>>>>>start training : ETTm1_512_96_DLinear_ETTm1_ftM_sl512_ll48_pl96_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 33953
# val 11425
# test 11425
# 	iters: 100, epoch: 1 | loss: 0.2860297
# ...

# %%
# !sed -i 's/\r$//' scripts/EXP-LongForecasting/DLinear/ettm2.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/EXP-LongForecasting/DLinear/ettm2.sh

# 3. Chạy script
# !./scripts/EXP-LongForecasting/DLinear/ettm2.sh
# Out:
# Args in experiment:
# Namespace(is_training=1, model_id='ETTm2_512_96', model='DLinear', data='ETTm2', root_path='./dataset/', data_path='ETTm2.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=96, individual=False, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.05, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.001, des='Exp', loss='mse', lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# >>>>>>>start training : ETTm2_512_96_DLinear_ETTm2_ftM_sl512_ll48_pl96_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 33953
# val 11425
# test 11425
# 	iters: 100, epoch: 1 | loss: 0.1326496
# ...

# %%
# !sed -i 's/\r$//' scripts/EXP-LongForecasting/DLinear/exchange_rate.sh

# 2. Cấp quyền thực thi cho file
# !chmod +x scripts/EXP-LongForecasting/DLinear/exchange_rate.sh

# 3. Chạy script
# !./scripts/EXP-LongForecasting/DLinear/exchange_rate.sh
# Out:
# Args in experiment:
# Namespace(is_training=1, model_id='Exchange_512_96', model='DLinear', data='custom', root_path='./dataset/', data_path='exchange_rate.csv', features='M', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=96, individual=False, embed_type=0, enc_in=8, dec_in=7, c_out=7, d_model=512, n_heads=8, e_layers=2, d_layers=1, d_ff=2048, moving_avg=25, factor=1, distil=True, dropout=0.05, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=10, batch_size=8, patience=3, learning_rate=0.0005, des='Exp', loss='mse', lradj='type1', use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# >>>>>>>start training : Exchange_512_96_DLinear_custom_ftM_sl512_ll48_pl96_dm512_nh8_el2_dl1_df2048_fc1_ebtimeF_dtTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 4704
# val 665
# test 1422
# 	iters: 100, epoch: 1 | loss: 0.0918340
# ...
